# %% [markdown]
# ## Python Introduction
#   Only python 3x, Python 2 has been deprecated
#
# ### Python Installation
#   1) Online -> Google Colab
#
#   2) Offline -> Python Installation
#
#       Python : https://www.python.org/downloads/
#
#       Anaconda : https://www.anaconda.com/download
#
#   3) IDE :
#
#         PyCharm : https://www.jetbrains.com/pycharm/download/#section=windows
#
#         VS Code : https://code.visualstudio.com/download

# %% [markdown]
# ### Programming
#
# let assume a = 10, b = 20, c = a + b then what is c.?
#
# Answer: 30

# %%
a = 10
b = 20

c = a + b

# %%
c
# Out:
# 30

# %%
import sys

# %%
sys.version
# Out:
# '3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]'

# %% [markdown]
# ### Variables
#
# Primitive Data Type -> Int, String, float, Bool
#
# Non Primitive Data Type -> List, Tuple, Dict and Set

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
a = "welcome all"

# %%
type(a)
# Out:
# str

# %%
a = "A"

# %%
type(a)
# Out:
# str

# %%
x = 10.123

# %%
type(x)
# Out:
# float

# %%
b=True

# %%
type(b)
# Out:
# bool

# %%
a = 10
b = "welcome"

# %%
c = a + b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-1674f6151070> in <cell line: 1>()
# ----> 1 c = a + b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### Operators
#
#     Aggregate Operator
#           + , - , * , /, %
#
#     Comparison Operator
#           >, <, ==, !=

# %%
a = 10
b = 20

# %%
a + b
# Out:
# 30

# %%
a - b
# Out:
# -10

# %%
a * b
# Out:
# 200

# %%
a/b
# Out:
# 0.5

# %% [markdown]
# ### Conditional Statement

# %%
a == b
# Out:
# False

# %%
a = 10
b = 10

if a == b:
  c = 20
else:
  c = a + b

# %%
c
# Out:
# 20

# %%
a = 10
b = 10

if a == b:
  c = 20
  print("both variable are same")
elif a > b :
  print("a is greater than b")
elif a < b :
  print("a is less than b")
else:
  c = a + b
# Out:
# both variable are same

# %%
a = 10
b = 20

if a == b:
  c = 20
  print("both variable are same")
elif a > b :
  print("a is greater than b")
elif a < b :
  print("a is less than b")
else:
  c = a + b
# Out:
# a is less than b

# %%
c
# Out:
# 20

# %% [markdown]
# ### Looping Statement
#   For
#
#   While

# %% [markdown]
# #### For

# %%
a = [1,3,4,5,2,100]
b = 0
for i in a:
  print(i)
  b +=i

print("final b is ", b)
# Out:
# 1
# 3
# 4
# 5
# 2
# 100
# final b is  115

# %%
a = [1,3,4,5,2,100]
b = 0

for i in a:
  print(i)
  b = b + i
else:
  print("No elements found, so final sum of b is ", b)
# Out:
# 1
# 3
# 4
# 5
# 2
# 100
# No elements found, so final sum of b is  115

# %% [markdown]
# #### While

# %%
a = 10
b = 1
while a != b:
  print("a is not met with b", b)
  b = b + 1
else:
  print("b is equal to a", b)
# Out:
# a is not met with b 1
# a is not met with b 2
# a is not met with b 3
# a is not met with b 4
# a is not met with b 5
# a is not met with b 6
# a is not met with b 7
# a is not met with b 8
# a is not met with b 9
# b is equal to a 10

# %%
c = False
a = "aaaaaa"
b = "a"
while c != True:
  print("a is not met with b", b)
  b = b + "a"
  if a==b:
    c=True
else:
  print("b is equal to a", b)
# Out:
# a is not met with b a
# a is not met with b aa
# a is not met with b aaa
# a is not met with b aaaa
# a is not met with b aaaaa
# b is equal to a aaaaaa

# %% [markdown]
# ### Tomorrow
#
#   Functions:
#
# 1.   UDF (User Defined Function)
# 2.   BuiltIn Functions
# 3.   Lambda Expression
